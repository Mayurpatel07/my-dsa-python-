# %%
# normal Polymorphism 
class email :
    def send(self):
        print("email sent")
class sms :
    def send(self):
        print("sms sent")

n = sms()
n.send()
n = email()
n.send()
# notify = [sms(),email]    # using for loop 
# for i in notify :
#     print(i.send())
# Out:
# sms sent
# email sent

# %%
# polymorphism with inheritance 
class animal :
    def sound(self):
        print("animal sound")
class dog(animal) :
    def sound(self):
        print("dog sound")
class cat(animal) :
    def sound(self):
        print("cat sound")

a = cat()
a.sound()
a = dog()
a.sound()
# Out:
# cat sound
# dog sound
