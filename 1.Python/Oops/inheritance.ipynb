# %%
class Student :
    def __init__(self,name,age):
        self.name = name 
        self.age=age 
    def info(self) :
        print(self.name)
class b(Student):
    def __init(self,name,age):
        super().__init__(name,age)
    
        # print(self.name)


Studnet2 = b("mayur",11)
Studnet2.info()

# Studnet1.info()
# Out:
# mayur

# %%
# multilevel 
class person:
    def __init__(self,name):
        self.name = name         
class employee(person) :
    def __init__(self,name,id):
        super().__init__(name)
        self.id = id 
class manager(employee):
    def __init__(self,name,id,dept):
        super().__init__(name,id)
        self.dept = dept
    
m = manager("mayur",11,"it")
m.name
m.dept
# Out:
# 'it'

# %%
# Hierarchical
class account:
    def __init__(self,balance):
        self.balance = balance
class saving(account):
    def __init__(self,balance):
        super().__init__(balance)
        print(f"the balance is {self.balance} in saving Account")
class current(account):
    def __init__(self,balance):
        super().__init__(balance)
        print(f"the balance is {self.balance} in current Account")

a = current(1000)
b = saving(1000)
# Out:
# the balance is 1000 in current Account
# the balance is 1000 in saving Account

# %%
# multiple 
class father :
    def __init__(self,father_name):
        self.father_name = father_name
class mother :
    def __init__(self,mother_name):
        self.mother_name = mother_name
class child(father,mother):
    def __init__(self,father_name,mother_name):
        father.__init__(self,father_name)
        mother.__init__(self,mother_name)
f = child("hyy","rsn")
f.father_name
f.mother_name
# Out:
# 'rsn'
