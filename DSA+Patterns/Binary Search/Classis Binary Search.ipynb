# %%
# 704. Binary search

# nums = [-1,0,3,5,9,12] 
# target = 9
nums = [-1,0,3,5,9,12]
target = 3
left = 0 
right = len(nums)-1

while left<=right :
    mid = left+(right-left)//2
    if nums[mid]==target:
        print(mid)
        break
    elif nums[mid]<target:
        left = mid+1 
    else :
        right = mid-1
  
print(-1)
# Out:
# 2
# -1

# %%
# 69. Sqrt(x)   
x = 8
left = 0 
right = x
ans = 0 

while left <=right:
    mid = left+(right-left)//2
    sq = mid*mid
    if sq==x:
        ans = mid 
        break 
    elif sq>x :
        right = mid-1 
    else :
        ans = mid    
        left = mid+1
print(ans)
# Out:
# 2

# %%
# 35. Search Insert Position

nums = [1,3,5,7] 
target = 6

# method 1 using lower bound 
nums = [1,3,5,7] 
target = 2

left = 0 
right = len(nums)

while left<right:
    mid = left+(right-left)//2
    if nums[mid]>=target:
        right = mid 
    else :
        left = mid+1 
print(left)

# method 2
left = 0 
right = len(nums)-1
while left<=right:
    mid = left+(right-left)//2
    if nums[mid]==target:
        print(mid) 
        break
    elif nums[mid]<target: 
    
        left = mid +1 
    else :
        right = mid-1 
print(left)
# Out:
# 1
# 1

# %%
# Out:
# 1

# %%
# 33. Search in Rotated Sorted Array
nums = [4,5,6,7,0,1,2]
target = 6

Found = False
left = 0 
right = len(nums)-1 

while left < right :
    mid = left+(right-left)//2
    if nums[mid]>nums[right] :
        left = mid +1 
    else :
        right = mid 
pivot = right 

left = 0 
right = pivot-1

while left<=right :
    mid = left+(right-left)//2 
    if nums[mid]==target:
        print(mid)
        Found = True
        break
    elif nums[mid]<target:
        left = mid+1 
    else :
        right = mid -1 

left = pivot 
right = len(nums)-1
while left<=right :
    mid = left +(right-left)//2 
    if nums[mid]==target:
        print(mid)
        Found = True
        break
    elif nums[mid]<target:
         left = mid+1 
    else :
        right = mid -1

if Found == False :
    print(-1)
# Out:
# 2

# %%
# 33. Search in Rotated Sorted Array (Short Method )
nums = [4,5,6,7,0,1,2]
target = 7

left = 0 
right = len(nums)-1
while left < right :
    mid = left+(right-left)//2
    if nums[mid]>nums[right] :
        left = mid +1 
    else :
        right = mid 
pivot = right 

if nums[0]<target :
    left = 0 
    right = pivot -1 

while left <= right :
    mid = left+(right-left)//2
    if nums[mid]==target :
        print(mid)
        break 
    elif nums[mid]<target:
        left = mid +1 
    else :
        right = mid -1
# Out:
# 3

# %%
# 153. Find Minimum in Rotated Sorted Array

nums = [3,4,5,1,2]

left = 0 
right = len(nums)-1 

while left <right :
    mid = left+(right-left)//2 
    if nums[mid] > nums[right] :
        left = mid+1 
    else :
        right = mid 
print(nums[right])
# Out:
# 1

# %%
# 162. Find Peak Element
nums = [1,2,1,3,5,6,4]

left = 0 
right = len(nums)-1 
while left<right:
    mid = left+(right-left)//2 
    if nums[mid]<nums[mid+1]:
        left = mid+1 
    else :
        right = mid 

print(right)
# Out:
# 5

# %%
# 34. Find First and Last Position of Element in Sorted Array
nums = [5,7,7,8,8,10]
target = 8

left = 0 
right = len(nums)

while left < right :   #lower bound
    mid = left+(right-left)//2
    if nums[mid]>=target :
        right = mid 
    else :
        left = mid +1
ans = left
if nums[ans]!= target :  # check that is target exist or not 
    print(-1,-1)
else :
    left = 0    # upper bound 
    right = len(nums)
    while left < right :
        mid = left+(right-left)//2
        if nums[mid]>target :
            right = mid 
        else :
            left = mid +1
    print(ans,left-1)
# Out:
# 3 4

# %%
# 744. Find Smallest Letter Greater Than Target

letters = ["x","x","y","y"]
target = "z"

left = 0 
right = len(letters)

while left <right :
    mid = left +(right-left)//2 
    if letters[mid] > target:
        right = mid 
    else :
        left = mid +1
if left ==len(letters):
    print(letters[0]) 
else :
    print(letters[left])
# Out:
# x

# %%
# Out:
# f
